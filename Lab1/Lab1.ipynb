# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("sales.csv")
df
# Out:
#        order_id                        name           ordered_at   price  \
# 0         10000    "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00   $3.50
# 1         10000    "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00   $3.50
# 2         10001          "SORBET" Raspberry  2018-01-01 12:14:54   $2.50
# 3         10001                         NaN  2018-01-01 12:14:54   $1.50
# 4         10001   "CONE" Dipped Waffle Cone  2018-01-01 12:14:54   $3.50
# ...         ...                         ...                  ...     ...
# 29917     18452  "ICE CREAM" Dulce De Leche  2018-06-26 03:56:13  $-1.50
# 29918     12889  "ICE CREAM" Dark Chocolate  2018-03-03 10:06:21   $4.00
# 29919     14526    "ICE CREAM" Peanut Fudge  2018-04-05 17:33:24   $3.50
# 29920     19589   "CONE" Dipped Waffle Cone  2018-07-20 09:10:01   $3.50
# 29921     19270       "ICE CREAM" Earl Gray  2018-07-13 09:20:21   $0.50
#
#        quantity line_total
# 0             3     $10.50
# 1             1      $3.50
# ...

# %%
#df.head()
#df.head(num) #prints start num numbers
#df #Shows whole thing
#df.tail(num) #prints end num numbers 
#df.shape #prints rows and cols
#df.size #prints rows x cols
#df.sort_values(["name"]) #Alphabetical order by name
#df.sort_values(["name"]).reset_index() #Reset back to initial indexes 
#df["name"].value_counts() #Can only use value_counts on series of data not a data frame
df["name"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df["name"][5:10] #Can index these like a list
# Out:
# 5           "SORBET" Lychee
# 6                       NaN
# 7     "ICE CREAM" Earl Gray
# 8        "ICE CREAM" Matcha
# 9    "BEVERAGE" Iced Coffee
# Name: name, dtype: object

# %%
df[["order_id", "name"]][:15]
# Out:
#     order_id                        name
# 0      10000    "ICE CREAM" Peanut Fudge
# 1      10000    "ICE CREAM" Peanut Fudge
# 2      10001          "SORBET" Raspberry
# 3      10001                         NaN
# 4      10001   "CONE" Dipped Waffle Cone
# 5      10002             "SORBET" Lychee
# 6      10002                         NaN
# 7      10002       "ICE CREAM" Earl Gray
# 8      10003          "ICE CREAM" Matcha
# 9      10004      "BEVERAGE" Iced Coffee
# 10     10004         "BEVERAGE" Espresso
# 11     10004       "ICE CREAM" Mint Chip
# 12     10004         "CONE" Brownie Cone
# 13     10004  "ICE CREAM" Dulce De Leche
# 14     10005          "SORBET" Raspberry

# %%
#df["line_total_custom"] = df["price"] * df["quantity"] #Not going to work because price is a string
#df.drop("line_total_custom", axis=1) #Remove from the dataframe
#df = df.drop(0, axis=0) #Need to reassign the variable when manipulating otherwise it won't update
#df = df.drop("line_total_custom", axis=1)
#OR 
#df.drop("line_total_custom", axis=1, inplace=True) #This is the same as reassigning
#df
#df.drop("")

# %%
#df.loc[8] #remove a row from the data frame
#df.iloc[8] #removes the 8th index instead of the 8th label
#df.loc[4, "name"]

# %%
#VERY IMPORTANT
#df[df["quantity"] > 2] #Shows only the data where the quantity is greater than 2
#df = df[df["quantity"] < 2]
#df = df.reset_index()
df = df.set_index("order_id")
#df.set_index("order_id", inplace=True)
df
# Out:
#                                 name           ordered_at   price  quantity  \
# order_id
# 10000       "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00   $3.50         3
# 10000       "ICE CREAM" Peanut Fudge  2018-01-01 11:30:00   $3.50         1
# 10001             "SORBET" Raspberry  2018-01-01 12:14:54   $2.50         2
# 10001                            NaN  2018-01-01 12:14:54   $1.50         1
# 10001      "CONE" Dipped Waffle Cone  2018-01-01 12:14:54   $3.50         1
# ...                              ...                  ...     ...       ...
# 18452     "ICE CREAM" Dulce De Leche  2018-06-26 03:56:13  $-1.50         2
# 12889     "ICE CREAM" Dark Chocolate  2018-03-03 10:06:21   $4.00         3
# 14526       "ICE CREAM" Peanut Fudge  2018-04-05 17:33:24   $3.50         3
# 19589      "CONE" Dipped Waffle Cone  2018-07-20 09:10:01   $3.50         2
# 19270          "ICE CREAM" Earl Gray  2018-07-13 09:20:21   $0.50         2
#
#          line_total
# order_id
# ...

# %%
df.loc[10001]
# Out:
#                                name           ordered_at  price  quantity  \
# order_id
# 10001            "SORBET" Raspberry  2018-01-01 12:14:54  $2.50         2
# 10001                           NaN  2018-01-01 12:14:54  $1.50         1
# 10001     "CONE" Dipped Waffle Cone  2018-01-01 12:14:54  $3.50         1
#
#          line_total
# order_id
# 10001         $5.00
# 10001         $1.50
# 10001         $3.50

# %% [markdown]
# ## 1. Missing Data

# %%
df = df.dropna() #any non-specified rows or cols if axis is specified
#df = df.dropna(axis=1) #col 1 
#df = df.dropna(thresh=2) #deletes row if 2 missing vals

# %% [markdown]
# ## 2. Groupby

# %%
#df.groupby("name").mean()
#df.groupby("name").std()
#df.groupby("name").max()
#df.groupby("name").min()
#df.groupby("name").count()
#df.groupby("name").describe()
df.groupby("name").describe().transpose() #Shows transposed version
# Out:
# name            "BEVERAGE" Espresso  "BEVERAGE" Iced Coffee  "BEVERAGE" Tea  \
# quantity count          1026.000000             1053.000000      993.000000
#          mean              1.979532                1.960114        2.030211
#          std               0.808835                0.826328        0.823724
#          min               1.000000                1.000000        1.000000
#          25%               1.000000                1.000000        1.000000
#          50%               2.000000                2.000000        2.000000
#          75%               3.000000                3.000000        3.000000
#          max               3.000000                3.000000        3.000000
#
# name            "CONE" Brownie Cone  "CONE" Cookie Cone  \
# quantity count          1048.000000         1080.000000
#          mean              2.013359            1.975926
#          std               0.819889            0.816520
#          min               1.000000            1.000000
# ...

# %%
#pd.concat([df1, df2, df3], axis=1)

# %%
#df["name"].nunique()
def squared(x):
    return x**2
df["quantity"].apply(squared)
df["quantity"].sum()
# Out:
# 56925

# %%
df.sort_values(by="quantity")
# Out:
#                                    name           ordered_at  price  quantity  \
# order_id
# 13724     "ICE CREAM" Maple Brown Sugar  2018-03-20 04:57:00  $2.00         1
# 12839               "BEVERAGE" Espresso  2018-03-02 07:32:14  $2.50         1
# 12839        "ICE CREAM" Dulce De Leche  2018-03-02 07:32:14  $1.50         1
# 19087     "ICE CREAM" Maple Brown Sugar  2018-07-09 04:01:29  $2.00         1
# 15759          "ICE CREAM" Peanut Fudge  2018-05-01 04:36:26  $3.50         1
# ...                                 ...                  ...    ...       ...
# 14960                 "CONE" Sugar Cone  2018-04-14 08:53:11  $1.00         3
# 14960             "MISC" Ice Cream Cake  2018-04-14 08:53:11  $2.00         3
# 14962                    "BEVERAGE" Tea  2018-04-14 09:56:10  $4.00         3
# 14952            "ICE CREAM" Strawberry  2018-04-14 05:19:42  $3.50         3
# 14979         "ICE CREAM" Candied Bacon  2018-04-14 17:45:06  $0.50         3
#
#          line_total
# ...
