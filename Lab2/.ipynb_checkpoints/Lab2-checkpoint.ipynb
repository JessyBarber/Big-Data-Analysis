# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

#Load job market
df = pd.read_csv('job-market.csv')
df = df.dropna(subset=['Title'])
df.head(3)
# Out:
#            Id                                              Title  \
# 0  37404348.0                           Casual Stock Replenisher
# 1  37404337.0                           Casual Stock Replenisher
# 2  37404356.0  RETAIL SALES SUPERSTARS and STYLISTS Wanted - ...
#
#                Company                      Date               Location  \
# 0          Aldi Stores  2018-10-07T00:00:00.000Z                 Sydney
# 1          Aldi Stores  2018-10-07T00:00:00.000Z  Richmond & Hawkesbury
# 2  LB Creative Pty Ltd  2018-10-07T00:00:00.000Z               Brisbane
#
#                           Area              Classification  SubClassification  \
# 0  North West & Hills District  Retail & Consumer Products  Retail Assistants
# 1                          NaN  Retail & Consumer Products  Retail Assistants
# 2          CBD & Inner Suburbs  Retail & Consumer Products  Retail Assistants
#
#                                          Requirement FullDescription  \
# 0  Our Casual Stock Replenishers pride themselves...             NaN
# 1  Our Casual Stock Replenishers pride themselves...             NaN
# 2  BRAND NEW FLAGSHIP STORE OPENING - SUNSHINE PLAZA             NaN
#
#    LowestSalary  HighestSalary JobType
# 0           0.0           30.0     NaN
# 1           0.0           30.0     NaN
# 2           0.0           30.0     NaN

# %%
# %matplotlib inline

by_class = df.groupby(['Classification'], as_index=False)['Id'].count().sort_values(by='Id', ascending=False)
fig = plt.figure(figsize=(10, 10))
sns.barplot(data=by_class, x=by_class.Id, y=by_class.Classification)
plt.title("Jobs and Number of Postings")
plt.xlabel("Number of Postings")
plt.ylabel("Classification")
# Out:
# Text(0, 0.5, 'Classification')

# %%
import matplotlib
by_lowSal = df.groupby(['LowestSalary'], as_index=False).count()
by_lowSal['labels'] = by_lowSal['LowestSalary']
by_lowSal.head()
# Out:
#    LowestSalary    Id  Title  Company  Date  Location  Area  Classification  \
# 0           0.0  3894   3894     3571  3894      3894  2560            3894
# 1          30.0  1842   1842     1779  1842      1842  1082            1842
# 2          40.0  2519   2519     2373  2519      2519  1516            2519
# 3          50.0  1844   1844     1760  1844      1844  1234            1844
#
#    SubClassification  Requirement  FullDescription  HighestSalary  JobType  \
# 0               3894         3894             3737           3894     3740
# 1               1842         1842             1815           1842     1816
# 2               2519         2519             2474           2519     2475
# 3               1844         1844             1817           1844     1821
#
#    labels
# 0     0.0
# 1    30.0
# 2    40.0
# 3    50.0

# %%
colors = sns.color_palette('pastel')[0:5]
fig = plt.figure(figsize=(10, 10))
plt.pie(data=by_lowSal, x=by_lowSal.Id, labels=by_lowSal.labels, colors=colors, autopct='%0.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1db9b44f448>,
#   <matplotlib.patches.Wedge at 0x1db9b44fe48>,
#   <matplotlib.patches.Wedge at 0x1db9b458808>,
#   <matplotlib.patches.Wedge at 0x1db9b462288>],
#  [Text(0.38693785945960824, 1.029698544680343, '0.0'),
#   Text(-1.0883136102638538, 0.15991712139247855, '30.0'),
#   Text(-0.38757836308420895, -1.029457630244667, '40.0'),
#   Text(0.923929845284454, -0.5969536338717146, '50.0')],
#  [Text(0.21105701425069537, 0.5616537516438235, '38.56%'),
#   Text(-0.5936256055984657, 0.08722752075953374, '18.24%'),
#   Text(-0.21140637986411395, -0.5615223437698182, '24.94%'),
#   Text(0.5039617337915203, -0.3256110730209352, '18.26%')])

# %%
# %matplotlib inline
matplotlib.patches.Circle(xy = (by_lowSal.Id, by_lowSal.labels))

# %%
# %matplotlib inline
locationDf = df[df['Location'].isna()==False]
locationDf = locationDf.groupby('Location').count()
locationDf['Location'] = locationDf.index
locationDf['Count'] = locationDf["Id"]
locationDf.head(10)
# Out:
#                                        Id  Title  Company  Date  Area  \
# Location
# ACT                                   238    238      235   238     0
# Adelaide                              390    390      356   390     0
# Adelaide Hills & Barossa               19     19       18    19     0
# Albany & Great Southern                10     10       10    10     0
# Albury Area                            19     19       18    19     0
# Alice Springs & Central Australia      17     17       14    17     0
# Bairnsdale & Gippsland                 18     18       17    18     0
# Ballarat & Central Highlands           46     46       46    46     0
# Bendigo, Goldfields & Macedon Ranges   46     46       43    46     0
# Blue Mountains & Central West          42     42       41    42     0
#
#                                       Classification  SubClassification  \
# Location
# ACT                                              238                238
# Adelaide                                         390                390
# Adelaide Hills & Barossa                          19                 19
# Albany & Great Southern                           10                 10
# Albury Area                                       19                 19
# Alice Springs & Central Australia                 17                 17
# Bairnsdale & Gippsland                            18                 18
# Ballarat & Central Highlands                      46                 46
# Bendigo, Goldfields & Macedon Ranges              46                 46
# Blue Mountains & Central West                     42                 42
#
#                                       Requirement  FullDescription  \
# Location
# ACT                                           238              235
# Adelaide                                      390              374
# Adelaide Hills & Barossa                       19               19
# Albany & Great Southern                        10               10
# Albury Area                                    19               19
# Alice Springs & Central Australia              17               17
# Bairnsdale & Gippsland                         18               18
# Ballarat & Central Highlands                   46               42
# Bendigo, Goldfields & Macedon Ranges           46               44
# Blue Mountains & Central West                  42               42
#
#                                       LowestSalary  HighestSalary  JobType  \
# Location
# ACT                                            238            238      236
# Adelaide                                       390            390      374
# Adelaide Hills & Barossa                        19             19       19
# Albany & Great Southern                         10             10       10
# Albury Area                                     19             19       19
# Alice Springs & Central Australia               17             17       17
# Bairnsdale & Gippsland                          18             18       18
# Ballarat & Central Highlands                    46             46       42
# Bendigo, Goldfields & Macedon Ranges            46             46       44
# Blue Mountains & Central West                   42             42       42
#
#                                                                   Location  \
# Location
# ACT                                                                    ACT
# Adelaide                                                          Adelaide
# Adelaide Hills & Barossa                          Adelaide Hills & Barossa
# Albany & Great Southern                            Albany & Great Southern
# Albury Area                                                    Albury Area
# Alice Springs & Central Australia        Alice Springs & Central Australia
# Bairnsdale & Gippsland                              Bairnsdale & Gippsland
# Ballarat & Central Highlands                  Ballarat & Central Highlands
# Bendigo, Goldfields & Macedon Ranges  Bendigo, Goldfields & Macedon Ranges
# Blue Mountains & Central West                Blue Mountains & Central West
#
#                                       Count
# Location
# ACT                                     238
# Adelaide                                390
# Adelaide Hills & Barossa                 19
# Albany & Great Southern                  10
# Albury Area                              19
# Alice Springs & Central Australia        17
# Bairnsdale & Gippsland                   18
# Ballarat & Central Highlands             46
# Bendigo, Goldfields & Macedon Ranges     46
# Blue Mountains & Central West            42

# %%
#Sort by descending to have the top 5 countries at the top
locationDf = locationDf.sort_values(by="Count", ascending=False)
#Copy the top 5 countries
df2 = locationDf[:5].copy()
#Add a new row that will be all of the countries under the top 5, rename to
#others and set as the sum of all of their counts
new_row = pd.DataFrame(data = {'Location' : ['others'],
                              'Count' : [locationDf['Count'][5:].sum()]
                              })
#Overwrite the dataframe with the concatenation of these two
locationDf = pd.concat([df2, new_row])

# %%
colors = sns.color_palette('pastel')[0:6]
fig = plt.figure(figsize=(10, 10))
plt.pie(data=locationDf, x=locationDf.Count, labels=locationDf.Location, colors=colors, autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1db9b46e288>,
#   <matplotlib.patches.Wedge at 0x1db9ba73ac8>,
#   <matplotlib.patches.Wedge at 0x1db9ba6f848>,
#   <matplotlib.patches.Wedge at 0x1db9b31a808>,
#   <matplotlib.patches.Wedge at 0x1db9b4989c8>,
#   <matplotlib.patches.Wedge at 0x1db9b61d308>,
#   <matplotlib.patches.Wedge at 0x1db9b61dc88>],
#  [Text(0.712628409045105, 0.8379503270611227, 'Sydney'),
#   Text(-0.8838052962141401, 0.6548955629593441, 'Melbourne'),
#   Text(-0.9745881422125005, -0.5100764188421057, 'Brisbane'),
#   Text(-0.5560145915145058, -0.9491300090203435, 'Perth'),
#   Text(-0.21638199704279493, -1.0785076872029111, 'Adelaide'),
#   Text(0.004619525933921839, -1.0999902999482067, 'Gold Coast'),
#   Text(0.8101922708529106, -0.7440352708374813, 'others')],
#  [Text(0.38870640493369363, 0.4570638147606123, '27.6%'),
#   Text(-0.4820756161168036, 0.3572157616141877, '24.6%'),
#   Text(-0.5315935321159093, -0.2782235011866031, '11.1%'),
#   Text(-0.3032806862806395, -0.51770727764746, '6.7%'),
#   Text(-0.11802654384152449, -0.5882769202924969, '3.9%'),
#   Text(0.002519741418502821, -0.5999947090626582, '2.6%'),
#   Text(0.44192305682886024, -0.40583742045680793, '23.6%')])
